# %%
import sys
from pathlib import Path

repo_root = Path.cwd()
sys.path.append(str(repo_root.parent / "src"))

# %%
from ingestion.load_redial_action import load_redial_action, quick_stats
import pandas as pd

# %%
df_redial_action = load_redial_action("../data/raw/ReDial-action.txt")
quick_stats(df_redial_action)
df_redial_action.head()
# Out:
# Rows: 4583
# Conversations: 336
# Speakers: {'SYSTEM': 2322, 'USER': 2261}
#    conv_id  turn_id speaker  \
# 0        0        1    USER
# 1        0        2  SYSTEM
# 2        0        3    USER
# 3        0        4  SYSTEM
# 4        0        5    USER
#
#                                                 text    dialog_act scores_raw  \
# 0           Hi can you help me find a movie to watch     AskForRec       None
# 1             Yes, how about @187028 <It  (2017)>  ?     Recommend       None
# 2  I don't really like horror movies what about t...  GiveFeedback       None
# 3        @203424 <The Silence of the Lambs  (1991)>      Recommend       None
# 4  I have seen it and enjoyed it...One of my favo...    AddDetails       None
#
#   scores  is_overall
# 0   None       False
# 1   None       False
# 2   None       False
# 3   None       False
# 4   None       False

# %%
df_redial_action.to_parquet("../data/processed/redial_action_turns.parquet", index=False)
print("Saved redial_action_turns.parquet")
# Out:
# Saved redial_action_turns.parquet
